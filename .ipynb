# %% [markdown]
# # All The Questions So Far:

# %% [markdown]
# **If I am importing additional libraries, where am I importing them from? And to where are they being 'installed'? I'm not even sure that's the right word to use.**

# %% [markdown]
# **Does 'bash' just mean I'm using commands from a console environment?**

# %% [markdown]
# ![image.png](attachment:image.png)
#
# **What is the 'memory' described?**

# %% [markdown]
# **It doesn't look like screenshots get added to the directory of a Jupyter Notebook. How are images stored?**

# %% [markdown]
# **Should I already be proficient in using Plotly or Pandas?**
